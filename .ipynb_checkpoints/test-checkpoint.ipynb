# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(10)
x = np.random.normal(100, 70, 200)
fig = plt.figure(figsize=(10, 7))
plt.hist(x)
# Out:
# (array([ 1.,  6.,  9., 14., 43., 45., 40., 26.,  8.,  8.]),
#  array([-108.57177397,  -70.44103918,  -32.31030439,    5.8204304 ,
#           43.9511652 ,   82.08189999,  120.21263478,  158.34336957,
#          196.47410437,  234.60483916,  272.73557395]),
#  <BarContainer object of 10 artists>)
